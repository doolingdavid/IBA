# %% [markdown]
# # <span style=" color: Blue;">PlaidCloud Analyze</span>
# <span style="color:'MidnightBlue;">Angela Grate</span>
# ![caption](https://pbs.twimg.com/profile_images/1149501773/plaidcloud-logo-only_400x400.jpeg)

# %% [markdown]
# # <span style="color: RoyalBlue;"> Overview</span>
#
# <span style="color: MidnightBlue;">
# - Introduction
# - Purpose of Analyze
# - Connectability
# - Analyze functions
# - Demo
# - Tips & Tricks
# - Updates
# - Help
# - Employment</span>

# %% [markdown]
# ### <span style= "color: RoyalBlue;">Tartan Solutions</span>
# <span style="color: 'MidnightBlue;">business and consulting PCM implementation</span>

# %% [markdown]
# ###<span style= "color: RoyalBlue;">PlaidCloud</span>
# <span style="color: 'MidnightBlue;">Analyze, Profit, Project, Tools, Document, PlaidXL</span>

# %% [markdown]
# ###<span style= "color: RoyalBlue;">Angela Grate</span>
# <span style="color: 'MidnightBlue;">Business Analyst, junior at Capital University</span>

# %% [markdown]
# ## <span style= "color: RoyalBlue;">The Need for Analyze</span>
#
# <span style= "color: MidnightBlue;">
# "We knew there was a better way of approaching data sourcing,
# transformation, and staging than using spreadsheets, desktop databases,
# or waiting on core systems teams to build transformation processes for us."
#                                     *Paul Morel and Michael Rea, founders.*</span>

# %% [markdown]
# ## <span style= "color: RoyalBlue;">What Analyze Does</span>
# <span style= "color: MidnightBlue;">
# - Data analysis
# - Flexibility solves large scale analytical problems
# - Interacts with iPython Notebook
# - Designed to work with different data platforms
# - Runs models, PoC </span>

# %% [markdown]
# ###<span style= "color: MidnightBlue;">PlaidCloud's Data Flexibility</span>
# ![Imgur](http://i.imgur.com/YOLXMDl.png)

# %% [markdown]
# ###<span style= "color: MidnightBlue;">Accessing the iPython Notebook Server</span>![Imgur](http://i.imgur.com/SqyZoNo.png)

# %% [markdown]
# ###<span style= "color: MidnightBlue;">The PlaidCloud to iPython Notebook Capability Yields Excellent Results for Visualization</span>

# %% [markdown]
# ####<span style= "color: DodgerBlue;">matplotlib</span>

# %%
# %pylab inline
x =linspace(0, 3*pi, 500)
plot(x, sin(x**2))
title('A simple chirp')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['show', 'figure', 'colors']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ####<span style= "color: DodgerBlue;">More exciting...Bokeh</span>

# %%
from bokeh.io import output_notebook

# %%
from bokeh.resources import CDN
from bokeh.plotting import figure, show

# %%
output_notebook(resources=CDN)
# Out:
#
#         <link rel="stylesheet" href="http://cdn.pydata.org/bokeh/release/bokeh-0.8.2.min.css" type="text/css" />
#         <script type="text/javascript" src="http://cdn.pydata.org/bokeh/release/bokeh-0.8.2.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
#     <p style="background-color: #f2d7dc;">Warning: BokehJS previously loaded</p>

# %%
N = 4000

# %%
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ["#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]

# %%
p = figure()
p.triangle(x, y, radius=radii, fill_color=colors, fill_alpha=1.5, line_color=None)

# %%
show(p)
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
#             var modelid = "7304e5cf-a51c-4bdd-9069-2c29137c9624";
#             var modeltype = "Plot";
#             var elementid = "cac2013c-757b-44b4-9ef9-52d657dab663";
#             Bokeh.logger.info("Realizing plot:")
#             Bokeh.logger.info(" - modeltype: Plot");
#             Bokeh.logger.info(" - modelid: 7304e5cf-a51c-4bdd-9069-2c29137c9624");
#             Bokeh.logger.info(" - elementid: cac2013c-757b-44b4-9ef9-52d657dab663");
# ...

# %%
from bokeh.io import output_notebook
from bokeh.resources import CDN
from bokeh.plotting import figure, show
output_notebook(resources=CDN)
# Out:
#
#         <link rel="stylesheet" href="http://cdn.pydata.org/bokeh/release/bokeh-0.8.2.min.css" type="text/css" />
#         <script type="text/javascript" src="http://cdn.pydata.org/bokeh/release/bokeh-0.8.2.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
#     <p style="background-color: #f2d7dc;">Warning: BokehJS previously loaded</p>

# %%
from bokeh.charts import HeatMap, output_file, show
from bokeh.palettes import YlOrRd9 as palette
from bokeh.sampledata.unemployment1948 import data

# %%
df = data[data.columns[:-1]]
df2 = df.set_index(df[df.columns[0]].astype(str))
df2.drop(df.columns[0], axis=1, inplace=True)
df3 = df2.transpose()

output_file("cat_heatmap.html")

palette = palette[::-1]  
hm = HeatMap(df3, title="categorical heatmap", width=800, palette=palette)

# %%
show(hm)
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
#             var modelid = "5a6289ef-ba39-41b3-9ada-1c45a9c1c7bb";
#             var modeltype = "Plot";
#             var elementid = "b040eb72-0191-41ea-a748-3e747f95d1eb";
#             Bokeh.logger.info("Realizing plot:")
#             Bokeh.logger.info(" - modeltype: Plot");
#             Bokeh.logger.info(" - modelid: 5a6289ef-ba39-41b3-9ada-1c45a9c1c7bb");
#             Bokeh.logger.info(" - elementid: b040eb72-0191-41ea-a748-3e747f95d1eb");
# ...

# %% [markdown]
# ##[Bokeh Gallery](http://bokeh.pydata.org/en/latest/docs/gallery.html)

# %% [markdown]
# ##[Github Gallery](https://github.com/mbostock/d3/wiki/Gallery)

# %% [markdown]
# Get data from Quandl, data.gov, databases, google

# %% [markdown]
# ##[PlaidCloud Model](https://plaidcloud.com/client)

# %% [markdown]
# Explain BCS model, different transforms and functions of Analyze

# %% [markdown]
# Switch from demo model to my own side and show the 8 different types of data, then how to take those into iPython Notebook. Show simple pandas sharts and the capability of plotting with it.

# %% [markdown]
# [Python 2](US Cities population.ipynb)
# [Python 2](tom hanks.ipynb)
# [Python 2](Action Movie Data.ipynb)
# [Python 2](Total Crime Index.ipynb)
# [Python 2](Cities Population and Crime.ipynb)
# [Python 2](FBI Weapons.ipynb)
# [Python 2](Refugee Locations.ipynb)
# [Python 2](red lights.ipynb)
# [Python 2](movie financials.ipynb)

# %% [markdown]
# ###<span style= "color: RoyalBlue;">Now Hiring! Employment Opportunities:</span>
# <span style="color: Blue;">
# - angela.grate@tartansolutions.com
# - info@tartansolutions.com
# - https://tartansolutions.com/
# - https://plaidcloud.com/
# - Phone: +1 412-512-7900

# %% [markdown]
# #<span style="color: Blue;">Thank You!</span>![Imgur](http://i.imgur.com/JhUlmO6.png)
