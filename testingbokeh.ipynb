# %%
# %pylab inline
x =linspace(0, 3*pi, 500)
plot(x, sin(x**2))
title('A simple chirp')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from bokeh.io import output_notebook
from bokeh.resources import CDN
from bokeh.plotting import figure, show
output_notebook(resources=CDN)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b9c4b2f8-fe36-4c01-8d97-dd0061a4e306">Loading BokehJS ...</span>
#     </div>

# %%
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
#colors = ["#%02f%02f%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]
p = figure()
p.triangle(x, y, fill_alpha=1.5, line_color=None)

# %%
show(p)
# Out:
#     <div class="plotdiv" id="0c9c5d09-afd7-4449-b592-3f546f24d497"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0c9c5d09-afd7-4449-b592-3f546f24d497");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0c9c5d09-afd7-4449-b592-3f546f24d497' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a0de142a-c497-46e2-a09c-9a5317644388":{"roots":{"references":[{"attributes":{},"id":"c31bd990-9ec9-4f20-af4a-c97251e7fe77","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"60a8b406-5bb2-4fab-8b9a-c8ed17071b61","type":"BasicTickFormatter"},"plot":{"id":"6c98aced-85a5-40e8-8013-656dd3e9a469","subtype":"Figure","type":"Plot"},"ticker":{"id":"c101c8e1-ccf5-4afe-ade9-985eed06e90e","type":"BasicTicker"}},"id":"4ae4f9e2-df4a-43e8-b962-4bb48d0477b2","type":"LinearAxis"},{"attributes":{"plot":{"id":"6c98aced-85a5-40e8-8013-656dd3e9a469","subtype":"Figure","type":"Plot"}},"id":"ec633717-81ba-419b-b572-1a53658fe817","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"390fc705-3bcb-4e1d-b938-428a85e311b8","subtype":"Figure","type":"Plot"}},"id":"816e1e1d-e5a9-4bc3-95eb-56c04ca7d68a","type":"PanTool"},{"attributes":{"plot":{"id":"86f30c9d-b4c9-4e04-b534-99da11113ba2","subtype":"Figure","type":"Plot"}},"id":"82261fa8-2adc-48b2-b141-0b63a3fe650e","type":"PreviewSaveTool"},{"attributes":{"overlay":{"id":"76ce2549-1a9f-48e0-9961-a131fbd228c4","type":"BoxAnnotation"},"plot":{"id":"6c98aced-85a5-40e8-8013-656dd3e9a469","subtype":"Figure","type":"Plot"}},"id":"2e0c49ca-24d1-4e85-8db9-8ba359243763","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"6c98aced-85a5-40e8-8013-656dd3e9a469","subtype":"Figure","type":"Plot"},"ticker":{"id":"48958c6e-cdce-4e8c-86c4-97a712dcef3d","type":"BasicTicker"}},"id":"9a62c1a0-d8c7-470d-8bab-5adaa7619535","type":"Grid"},{"attributes":{"plot":{"id":"86f30c9d-b4c9-4e04-b534-99da11113ba2","subtype":"Figure","type":"Plot"}},"id":"c6341eae-1763-4293-a8c2-a875be37f5f0","type":"PanTool"},{"attributes":{"plot":{"id":"86f30c9d-b4c9-4e04-b534-99da11113ba2","subtype":"Figure","type":"Plot"}},"id":"b2c28d2a-8963-449d-b6a4-2c6127b8fb91","type":"ResetTool"},{"attributes":{"plot":{"id":"86f30c9d-b4c9-4e04-b534-99da11113ba2","subtype":"Figure","type":"Plot"}},"id":"8af036b9-5ab1-4999-a106-56ab5bc1451c","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9d7bae11-9eda-4e76-a7dd-237d07a7c635","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7af45c8a-a026-41b5-9bd1-87da1e45b4fe","type":"Triangle"},{"attributes":{"plot":{"id":"86f30c9d-b4c9-4e04-b534-99da11113ba2","subtype":"Figure","type":"Plot"},"ticker":{"id":"81f801bb-b258-487e-8e6d-320a08eed39e","type":"BasicTicker"}},"id":"f735c2d6-334a-4e57-a22f-4733b27478d6","type":"Grid"},{"attributes":{"plot":{"id":"6c98aced-85a5-40e8-8013-656dd3e9a469","subtype":"Figure","type":"Plot"}},"id":"103a8ed1-e059-40de-868e-692e191012e4","type":"HelpTool"},{"attributes":{"plot":{"id":"6c98aced-85a5-40e8-8013-656dd3e9a469","subtype":"Figure","type":"Plot"}},"id":"7bade1aa-9f93-45a6-9bf0-430f1a8207cc","type":"PanTool"},{"attributes":{"data_source":{"id":"43e41d11-bfa6-4299-9de3-f1236d387d52","type":"ColumnDataSource"},"glyph":{"id":"2b26aa91-e486-41b9-87af-65bbacaaaf47","type":"Triangle"},"hover_glyph":null,"nonselection_glyph":{"id":"7af45c8a-a026-41b5-9bd1-87da1e45b4fe","type":"Triangle"},"selection_glyph":null},"id":"4de2e604-f67d-403b-ba64-47b4dca8dfcc","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3600130a-dafa-4e5a-817d-2775d10defee","type":"BoxAnnotation"},{"attributes":{},"id":"c101c8e1-ccf5-4afe-ad ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>
