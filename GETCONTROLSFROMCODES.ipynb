# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import pytz
from pytz import common_timezones, all_timezones
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline
from datetime import datetime
import scipy as spsa
import statsmodels.api as sm
import statsmodels.formula.api as smf
matplotlib.style.use('fivethirtyeight')
matplotlib.style.use('seaborn-talk')
import os
import collections

# %%
prepath = '\\\\iobsdc01\\SharedDocs\\SEER_MEDICARE\\SEER_MEDICARE_STAGING'
#filetest = 'pedsf.nasopharynx.cancer.txt'
filetest = 'outsaf09.file1.txt'
testfile = prepath+filetest
testfile
# Out:
# '\\\\iobsdc01\\SharedDocs\\SEER_MEDICARE\\SEER_MEDICARE_STAGINGoutsaf09.file1.txt'

# %%
preDouble = "\\\\iobsdc01\\SharedDocs\\SEER_MEDICARE\\SEER_MEDICARE_STAGING"
new = os.chdir(preDouble)
print(preDouble)
# Out:
# \\iobsdc01\SharedDocs\SEER_MEDICARE\SEER_MEDICARE_STAGING

# %%
specsdict = {'patient_id': (0,0+11),
            'casereg': (0,0+2),
             'hcpcs': (240,240+5),
             'mf1': (245,245+2),
             'mf2': (247,247+2),
             'mf3': (249,249+2)}

names = sorted(specsdict,key=specsdict.__getitem__)

colspecs = [specsdict[n] for n in names]

# %%
import glob
#filelist = glob.glob('./outsaf*')
filelist = glob.glob('outsaf*')
goodfilelist = [f for f in filelist if f.endswith('.txt')]
goodfilelist[:15]
# Out:
# ['outsaf06.file001.txt',
#  'outsaf06.file002.txt',
#  'outsaf06.file003.txt',
#  'outsaf06.file004.txt',
#  'outsaf06.file005.txt',
#  'outsaf06.file006.txt',
#  'outsaf06.file007.txt',
#  'outsaf06.file008.txt',
#  'outsaf06.file009.txt',
#  'outsaf06.file010.txt',
#  'outsaf06.file011.txt',
#  'outsaf06.file012.txt',
#  'outsaf06.file013.txt',
#  'outsaf06.file014.txt',
#  'outsaf06.file015.txt']

# %%
len(goodfilelist)
# Out:
# 218

# %%
df = pd.read_fwf(goodfilelist[0], colspecs = colspecs,
                names=names)

df.patient_id = df.patient_id.astype(str)
df.patient_id = df.patient_id.apply(lambda x: x.rjust(10, '0'))

df.set_index('patient_id', inplace=True,drop=False)

# %%
df.patient_id.head()
# Out:
# patient_id
# 0200021629    0200021629
# 0200021629    0200021629
# 0200021629    0200021629
# 0200021629    0200021629
# 0200021629    0200021629
# Name: patient_id, dtype: object

# %%
len(str(df.patient_id.iloc[0]))
# Out:
# 10

# %%
N = 5
fin = goodfilelist[0]
from itertools import islice
with open(fin) as myfile:
    head = list(islice(myfile, N))
print(head)
# Out:
# ['0200021629 A 07000X5751    10400703200607032006003080704753131            62.45         267.00            0.00107          B68635                                          01 00505                                   0501030007032006     0000036415       210B             0.000       1           3.00           0.00           0.00           0.00           3.00           0.00          18.00           3.00           0.003 A 20060000564998120520090101001           0.00           0.00           0.00          62.45  0  0C                                                   7310                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              \n', '0200021629 A 07000X5751    10400703200607032006003080704753131            62.45         267.00            0.00107          B68635                                          01 00505                                   0501030007032006     000008252359     210B             0.000       1          26.11           0.00           0.00           0.00          26.11           0.00          41.00          26.11           0.003 A 20060000564998120520090101002           0.00           0.00           0.00          62.45  0  0C                                                   7310                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              \n', '0200021629 A 07000X5751    10400703200607032006003080704753131            62.45         267.00            0.00107          B68635                                          01 00505                                   0501030107032006     0000082523       210B             0.000       1          26.11           0.00           0.00           0.00          26.11           0.00         185.00          26.11           0.003 A 20060000564998120520090101003           0.00           0.00           0.00          62.45  0  0C                                                   7310                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              \n', '0200021629 A 07000X5751    10400703200607032006003080704753131            62.45         267.00            0.00107          B68635                                          01 00505                                   0501030107032006     0000084075       210B             0.000       1           7.23           0.00           0.00           0.00           7.23           0.00          23.00           7.23           0.003 A 20060000564998120520090101004           0.00           0.00           0.00          62.45  0  0C                                                   7310                   ...

# %%
'36415' in df.hcpcs.values
# Out:
# True

# %%
'77520' in df.hcpcs.values
# Out:
# True

# %%
treatmentgoodcodes = ['77520', '77522', '77523', '77525', 
             'S8030']

goodcodes = ['77401',
 '77402',
 '77403',
 '77404',
 '77405',
 '77406',
 '77407',
 '77408',
 '77409',
 '77410',
 '77411',
 '77412',
 '77413',
 '77414',
 '77415',
 '77416',
 '77417',
 '77418',
 '77419',
 '77420',
 '77421',
 '77422',
 '77423',
 '77424',
 '77425',
 '77521',
 '77524',
 '77750',
 '77751',
 '77752',
 '77753',
 '77754',
 '77755',
 '77756',
 '77757',
 '77758',
 '77759',
 '77760',
 '77761',
 '77762',
 '77763',
 '77764',
 '77765',
 '77766',
 '77767',
 '77768',
 '77769',
 '77770',
 '77771',
 '77772',
 '77773',
 '77774',
 '77775',
 '77776',
 '77777',
 '77778',
 '77779',
 '77780',
 '77781',
 '77782',
 '77783',
 '77784',
 '77785',
 '77786',
 '77787',
 '77788',
 '77789',
 '77790',
 '77791',
 '77792',
 '77793',
 '77794',
 '77795',
 '77796',
 '77797',
 '77798',
 '77799',
 'G0173',
 'G0251',
 'G0256',
 'G0261',
 'G0339',
 'G0340']

# %%
good_patients = df.hcpcs.isin(goodcodes) & ~df.hcpcs.isin(treatmentgoodcodes)

# %%
good_patients.shape
# Out:
# (519999,)

# %%
good_patients.head()
# Out:
# patient_id
# 0200021629    False
# 0200021629    False
# 0200021629    False
# 0200021629    False
# 0200021629    False
# Name: hcpcs, dtype: bool

# %%
good_patients.sum()
# Out:
# 34733

# %%
set(df.patient_id[good_patients].index)
# Out:
# {'0230403000',
#  '0239474020',
#  '0200211019',
#  '0231477030',
#  '0229497070',
#  '0221472060',
#  '0235487010',
#  '0239458090',
#  '0223475070',
#  '0230445020',
#  '0239417000',
#  '0239445020',
#  '0220485090',
#  '0231439070',
#  '0229482090',
#  '0225109100',
#  '0238492040',
#  '0223430040',
#  '0235436040',
#  '0227442070',
#  '0220493040',
#  '0235476060',
#  '0237073843',
#  '0237486080',
#  '0249462000',
#  '0230442070',
#  '0232478010',
#  '0235495000',
#  '0234445020',
#  '0234446060',
#  '0230499060',
#  '0234483080',
#  '0217491080',
#  '0238425050',
#  '0225439050',
#  '0233474080',
#  '0223457070',
#  '0225440080',
#  '0240452030',
#  '0244431000',
#  '0238400060',
#  '0232498020',
#  '0214206296',
#  '0233472090',
#  '0242402000',
#  '0233407010',
#  '0224490090',
#  '0236436000',
#  '0221470080',
#  '0225453090',
#  '0229485090',
#  '0221442070',
#  '0221432060',
#  '0222459080',
#  '0221435070',
#  '0236410020',
#  '0220450070',
#  '0234493050',
#  '0222456050',
#  '0222470090',
#  '0232436010',
#  '0234428000',
#  '0237468000',
#  '0230499020',
#  '0235484030',
#  '0238476010',
#  '0232479080',
#  '0230448000',
#  '0205231324',
#  '0222452060',
#  '0236419020',
#  '0240404000',
#  '0242430010',
#  '0249424010',
#  '0233413000',
#  '0233411090',
#  '0235496030',
#  '0241402000',
#  '0236417020',
#  '0228012830',
#  '0224452070',
#  '0223480050',
#  '0230448050',
#  '0236466030',
#  '0237468020',
#  '0232450050',
#  '0239476050',
#  '0261205472',
#  '0226446070',
#  '0210419040',
#  '0228460090',
#  '0231452030',
#  '0234461050',
#  '0213095606',
#  '0236451030',
#  '0236457080',
#  '0237457050',
#  '0239433000',
#  '0239481090',
#  '0224472040',
#  '0224454090',
#  '0233498080',
#  '0241151035',
#  '0262263152',
#  '0253257225',
#  '0223474080',
#  '0244413000',
#  '0249010655',
#  '0249429010',
#  '0235438040',
#  '0231480090',
#  '0228483060',
#  '0230410070',
#  '0236485010',
#  '0238445070',
#  '0239402080',
#  '0240410010',
#  '0249478020',
#  '0244475020',
#  '0235479030',
#  '0232407000',
#  '0236404070',
#  '0239409030',
#  '0231435000',
#  '0235409020',
#  '0249451010',
#  '0202484000',
#  '0221447050',
#  '0221428060',
#  '0234423050',
#  '0227445040',
#  '0231499070',
#  '0229424070',
#  '0243403020',
#  '0228460070',
#  '0224424090',
#  '0237421060',
#  '0234428030',
#  '0229491070',
#  '0227383004',
#  '0243268296',
#  '0200402070',
#  '0237425080',
#  '0237401020',
#  '0235460040',
#  '0238293328',
#  '0230443090',
#  '0222488070',
#  '0230456050',
#  '0232287039',
#  '0238470010',
#  '0242433000',
#  '0234490030',
#  '0238095679',
#  '0222410070',
#  '0235416040',
#  '0235489030',
#  '0232424060',
#  '0236427020',
#  '0238455090',
#  '0211377044',
#  '0237481090',
#  '0225465090',
#  '0236421020',
#  '0238445000',
#  '0238466040',
#  '0225473080',
#  '0223417090',
#  '0238498030',
#  '0233412070',
#  '0236470030',
#  '0239490070',
#  '0220487040',
#  '0239477090',
#  '0222420070',
#  '0236475030',
#  '0240424020',
#  ...}

# %% [markdown]
# ## Need to make this process into a function that can loop through all the outsaf files; collect the unique patient ids and accumulate them.

# %%
specsdict = {'patient_id': (0,0+11),
            'casereg': (0,0+2),
             'hcpcs': (240,240+5),
             'mf1': (245,245+2),
             'mf2': (247,247+2),
             'mf3': (249,249+2)}

names = sorted(specsdict,key=specsdict.__getitem__)

colspecs = [specsdict[n] for n in names]

import glob
#filelist = glob.glob('./outsaf*')
filelist = glob.glob('outsaf*')
goodfilelist = [f for f in filelist if f.endswith('.txt')]

# %%
def get_patients_from_file(fin):
    """takes as input the filename, reads it and returns a 
    set containing the patient_id of those who have received PT."""
    
    df = pd.read_fwf(fin, colspecs = colspecs,
                names=names)

    df.patient_id = df.patient_id.astype(str)
    df.patient_id = df.patient_id.apply(lambda x: x.rjust(10, '0'))

    df.set_index('patient_id', inplace=True,drop=False)
    
    
    
    
    good_patients = df.hcpcs.isin(goodcodes) & ~df.hcpcs.isin(treatmentgoodcodes)
    
    
    good_set = set(df.patient_id[good_patients].index)
    
    del df
    
    return good_set

# %% [markdown]
# ## Need to combine the sets returned by the above function.

# %%
set0 = get_patients_from_file(goodfilelist[0])

# %%
set1 = get_patients_from_file(goodfilelist[1])

# %%
print(set0)
# Out:
# {'0230403000', '0239474020', '0200211019', '0231477030', '0229497070', '0221472060', '0235487010', '0239458090', '0223475070', '0230445020', '0239417000', '0239445020', '0220485090', '0231439070', '0229482090', '0225109100', '0238492040', '0223430040', '0235436040', '0227442070', '0220493040', '0235476060', '0237073843', '0237486080', '0249462000', '0230442070', '0232478010', '0235495000', '0222416060', '0226472080', '0231410030', '0218134058', '0222409090', '0230418010', '0226459080', '0225465040', '0230407050', '0235424040', '0238465010', '0230409070', '0239429080', '0220490070', '0228442050', '0229477090', '0235406010', '0237414030', '0216219188', '0234410010', '0232449040', '0249476000', '0227459040', '0235407090', '0229480060', '0230422020', '0236465060', '0242416020', '0233463030', '0223441040', '0237403030', '0221484090', '0231419010', '0233444030', '0237443090', '0225450060', '0233421010', '0244441020', '0234404020', '0242496010', '0245441000', '0239415020', '0232491060', '0233475030', '0232402000', '0234490070', '0245436020', '0235409000', '0229444080', '0237400070', '0241403000', '0218173142', '0223444060', '0230461000', '0223408070', '0227471090', '0240498000', '0232482000', '0239440060', '0238459090', '0213436020', '0240417010', '0228467050', '0230405000', '0226476080', '0230445000', '0242391073', '0215490030', '0229479090', '0223456080', '0206220041', '0247210392', '0239422080', '0220474090', '0230430080', '0241459000', '0230481080', '0238448090', '0239451050', '0245402000', '0247471010', '0225445050', '0256112038', '0235458060', '0237438000', '0216126057', '0220496090', '0236419000', '0238453000', '0237488050', '0228403070', '0233431090', '0234414010', '0232488010', '0224467070', '0239461040', '0233173099', '0234403040', '0235426050', '0242468000', '0220412080', '0221469090', '0226401080', '0239492000', '0227478090', '0226476070', '0238428080', '0239431030', '0228444070', '0234465030', '0239496070', '0229482080', '0226485090', '0236416020', '0238401010', '0239486060', '0222437070', '0220492040', '0223491070', '0225464000', '0233494010', '0263168044', '0234428060', '0206436010', '0227471060', '0262208225', '0222439060', '0239485090', '0225454090', '0227247430', '0239467050', '0205288156', '0238461010', '0238431090', '0234456050', '0235440000', '0227422070', '
# 14 12366
# 15 13054
# 16 13767
# 17 14445
# 18 15215
# 19 15925
# 20 16675
# 21 16756
# 22 18041
# 23 18983
# 24 20022
# 25 20540
# 26 21602
# 27 22082
# 28 22482
# 29 23749
# 30 24399
# 31 25147
# 32 25912
# 33 26647
# 34 27918
# 35 29752
# 36 30952
# 37 32025
# 38 32947
# 39 33486
# 40 34516
# 41 35406
# 42 36309
# 43 37176
# 44 38006
# 45 38870
# 46 39729
# 47 40114
# 48 40833
# 49 41940
# 50 42775
# 51 43535
# 52 44341
# 53 45028
# 54 45644
# 55 46481
# 56 47393
# 57 48260
# 58 48567
# 59 49610
# 60 49933
# 61 50849
# 62 51731
# 63 53083
# 64 54478
# 65 55330
# 66 56440
# 67 56935
# 68 57605
# 69 58331
# 70 59031
# 71 59726
# 72 60510
# 73 61220
# 74 62033
# 75 62823
# 76 63274
# 77 64576
# 78 64926
# 79 66106
# 80 66663
# 81 67697
# 82 68180
# 83 69139
# 84 69815
# 85 70634
# 86 71545
# 87 71790
# 88 72650
# 89 72854
# 90 73844
# 91 75287
# 92 76384
# 93 77120
# 94 77648
# 95 78246
# 96 79228
# 97 80001
# 98 80785
# 99 81529
# 100 82248
# 101 82924
# 102 83565
# 103 84197
# 104 84865
# 105 85379
# 106 86443
# 107 87199
# 108 87866
# 109 88267
# 110 89195
# 111 89728
# 112 90531
# 113 91355
# 114 92132
# 115 92705
# 116 93269
# 117 94204
# 118 94449
# 119 95127
# 120 95570
# 121 96567
# 122 97238
# 123 98319
# 124 99438
# 125 100440
# 126 101184
# 127 101504
# 128 102138
# 129 102796
# 130 103441
# 131 104115
# 132 104771
# 133 105459
# 134 106116
# 135 106681
# 136 107116
# 137 108365
# 138 108905
# 139 109796
# 140 110376
# 141 110785
# 142 111154
# 143 112122
# 144 112787
# 145 113788
# 146 114353
# 147 114681
# 148 115471
# 149 116047
# 150 116407
# 151 117118
# 152 118038
# 153 119343
# 154 120372
# 155 120994
# 156 121487
# 157 122285
# 158 123315
# 159 124051
# 160 124655
# 161 125263
# 162 125914
# 163 126518
# 164 127076
# 165 127733
# 166 128470
# 167 129078
# 168 129222
# 169 129764
# 170 129956
# 171 130412
# 172 130603
# 173 130755
# 174 131158
# 175 131458
# 176 131915
# 177 132136
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-52-ca7b73d3dc15> in <module>()
#       2
#       3 for i in range(len(goodfilelist)):
# ----> 4     s = get_patients_from_file(goodfilelist[i])
#       5     allsetslist.append(s)
#       6     so_far = set.union(*allsetslist)
#
# <ipython-input-46-5566a482cecb> in get_patients_from_file(fin)
#       4
#       5     df = pd.read_fwf(fin, colspecs = colspecs,
# ----> 6                 names=names)
#       7
#       8     df.patient_id = df.patient_id.astype(str)
#
# C:\Users\ddooling\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_fwf(filepath_or_buffer, colspecs, widths, **kwds)
#     558     kwds['colspecs'] = colspecs
#     559     kwds['engine'] = 'python-fwf'
# --> 560     return _read(filepath_or_buffer, kwds)
#     561
#     562
#
# C:\Users\ddooling\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     303         return parser
#     304
# --> 305     return parser.read()
#     306
#     307 _parser_defaults = {
#
# C:\Users\ddooling\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#     761                 raise ValueError('skip_footer not supported for iteration')
#     762
# --> 763         ret = self._engine.read(nrows)
#     764
#     765         if self.options.get('as_recarray'):
#
# C:\Users\ddooling\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, rows)
#    1595     def read(self, rows=None):
#    1596         try:
# -> 1597             content = self._get_lines(rows)
#    1598         except StopIteration:
#    1599             if self._first_chunk:
#
# C:\Users\ddooling\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in _get_lines(self, rows)
#    2055                         while True:
#    2056                             try:
# -> 2057                                 new_rows.append(next(source))
#    2058                                 rows += 1
#    2059                             except csv.Error as inst:
#
# C:\Users\ddooling\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\io\parsers.py in __next__(self)
#    2434                 line = next(self.f)
#    2435         else:
# -> 2436             line = next(self.f)
#    2437         # Note: 'colspecs' is a sequence of half-open intervals.
#    2438         return [line[fromm:to].strip(self.delimiter)
#
# OSError: [Errno 22] Invalid argument

# %%
len(allsetslist)

# %%
import pickle
fileObject = open('control_patient_ids_from_outsaf.pickle', 'wb')
pickle.dump(allsetslist, fileObject)
fileObject.close()

# %%
fileObject = open('control_patient_ids_from_outsaf.pickle', 'rb')
b = pickle.load(fileObject)
fileObject.close()
allsetslist == b

# %% [markdown]
# ## Now need to get the patient_ids corresponding to the relevant HCPCS codes from carrier claims file
#
# specifically the column ```LINE HCPCS CODE```

# %%
specsdict = {'patient_id': (0,0+11),
            'hcpcs': (92,92+5),
            'mf1': (97,97+2),
            'mf2': (99,99+2),
            'mf3': (101,101+2),
            'mf4': (103,103+1)}

names = sorted(specsdict,key=specsdict.__getitem__)

colspecs = [specsdict[n] for n in names]

# %%
import glob
filelist = glob.glob('nch*')
goodfilelist = [f for f in filelist if f.endswith('.txt')]
goodfilelist[:15]

# %%
len(goodfilelist)

# %%
df = pd.read_fwf(goodfilelist[0], colspecs = colspecs,
                names=names)

df.patient_id = df.patient_id.astype(str)
df.patient_id = df.patient_id.apply(lambda x: x.rjust(10, '0'))

df.set_index('patient_id', inplace=True,drop=False)

# %%
df.patient_id.head()

# %%
len(str(df.patient_id.iloc[0]))

# %%
N = 5
fin = goodfilelist[0]
from itertools import islice
with open(fin) as myfile:
    head = list(islice(myfile, N))
print(head)

# %%
#goodcodes = ['77520', '77522', '77523', '77525', 
#             'S8030']

# %%
good_patients = df.hcpcs.isin(goodcodes) & ~df.hcpcs.isin(treatmentgoodcodes)

# %%
good_patients.shape

# %%
good_patients.head()

# %%
good_patients.sum()

# %%
allsetslist = []

for i in range(len(goodfilelist)):
    s = get_patients_from_file(goodfilelist[i])
    allsetslist.append(s)
    so_far = set.union(*allsetslist)
    print(i, len(list(so_far)))

# %%
import pickle
fileObject = open('control_patient_ids_from_nch.pickle', 'wb')
pickle.dump(allsetslist, fileObject)
fileObject.close()

# %%
fileObject = open('control_patient_ids_from_nch.pickle', 'rb')
b = pickle.load(fileObject)
fileObject.close()
allsetslist == b
